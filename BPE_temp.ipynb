# %%
from collections import Counter, defaultdict
import nltk

class BytePairEncoding:
    def __init__(self, num_merges):
        self.num_merges = num_merges
        self.vocab = None
        self.merges = []

    def _get_stats(self, vocab):
        """Count frequency of pairs of symbols in the vocabulary."""
        pairs = defaultdict(int)
        for word, freq in vocab.items():
            symbols = word.split()
            for i in range(len(symbols) - 1):
                pairs[(symbols[i], symbols[i + 1])] += freq
        return pairs

    def _merge_vocab(self, pair, vocab):
        """Merge the most frequent pair in the vocabulary."""
        new_vocab = {}
        bigram = ' '.join(pair)
        replacement = ''.join(pair)
        for word in vocab:
            # Replace all occurrences of the bigram with its replacement.
            new_word = word.replace(bigram, replacement)
            new_vocab[new_word] = vocab[word]
        return new_vocab

    def fit(self, corpus):
        """Train the Byte Pair Encoding model on the provided corpus."""
        # Initialize the vocabulary
        vocab = Counter()
        for word in corpus:
            # Clean the word by removing special characters and punctuation
            word = ''.join(char.lower() for char in word if char.isalnum())
            if word:  # Only process non-empty words
                tokens = ' '.join(word) + '_'
                vocab[tokens] += 1
        
        self.vocab = vocab

        for _ in range(self.num_merges):
            # Get the most frequent pair of symbols.
            pairs = self._get_stats(vocab)
            if not pairs:
                break
            best_pair = max(pairs, key=pairs.get)

            # Merge the most frequent pair.
            vocab = self._merge_vocab(best_pair, vocab)
            self.merges.append(best_pair)

        self.vocab = vocab

    def encode(self, word):
        """Encode a word using the learned merges."""
        # Clean the word by removing special characters and punctuation
        word = ''.join(char.lower() for char in word if char.isalnum())
        word = ' '.join(word) + '_'
        for pair in self.merges:
            bigram = ' '.join(pair)
            replacement = ''.join(pair)
            word = word.replace(bigram, replacement)
        return word.split()

    def decode(self, encoded_word):
        """Decode an encoded word back to its original form."""
        word = ' '.join(encoded_word)
        for pair in reversed(self.merges):
            replacement = ''.join(pair)
            bigram = ' '.join(pair)
            word = word.replace(replacement, bigram)
        return word.replace('_', '').replace(' ', '')

# %%
# Example Usage:
if __name__ == "__main__":
    corpus = ["low", "lowest", "newer", "wider"]
    nltk.download('gutenberg')
    from nltk.corpus import gutenberg
    book1 = gutenberg.raw("austen-emma.txt")
    book2 = gutenberg.raw("blake-poems.txt") 
    book3 = gutenberg.raw("shakespeare-hamlet.txt")
    
    training_text = book1 + " " +  book2 + " " + book3 + " " + "low"
    
    corpus = training_text.split()
    print(corpus[0])
    
    bpe = BytePairEncoding(num_merges=1000)
    bpe.fit(corpus)

    print("Learned merges:", bpe.merges)
    print("Vocabulary after training:", bpe.vocab)

    encoded_word = bpe.encode("lowest pi-chart")
    print("Encoded:", encoded_word)

    decoded_word = bpe.decode(encoded_word)
    print("Decoded:", decoded_word)
# Out:
# [nltk_data] Error loading gutenberg: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1000)>
# [Emma
# Learned merges: [('t', 'h'), ('a', 'n'), ('i', 'n'), ('e', 'r'), ('o', 'u'), ('h', 'a'), ('th', 'e_'), ('an', 'd_'), ('t', 'o_'), ('e', 'd_'), ('e', 'n'), ('in', 'g_'), ('e', 'a'), ('o', 'f_'), ('o', 'n'), ('h', 'e_'), ('e', 'l'), ('n', 'o'), ('a', 's_'), ('h', 'i'), ('o', 'r'), ('e', 's'), ('t', 'i'), ('a', 'r'), ('i', 't_'), ('a', 'l'), ('w', 'i'), ('l', 'd_'), ('no', 't_'), ('o', 'm'), ('h', 'er_'), ('w', 'as_'), ('y', 'ou_'), ('r', 'i'), ('l', 'y_'), ('s', 'he_'), ('r', 'e'), ('g', 'h'), ('b', 'e'), ('v', 'e_'), ('i', 's'), ('l', 'e_'), ('ou', 'ld_'), ('tha', 't_'), ('s', 'u'), ('s', 't_'), ('b', 'u'), ('c', 'h_'), ('l', 'i'), ('v', 'er'), ('e', 'm'), ('c', 'e_'), ('ver', 'y_'), ('bu', 't_'), ('s', 'a'), ('s', 'e_'), ('ha', 'd_'), ('a', 't'), ('m', 'e_'), ('f', 'or_'), ('o', 'o'), ('wi', 'th_'), ('s', 'i'), ('w', 'h'), ('s', 't'), ('l', 'e'), ('l', 'l_'), ('m', 'u'), ('r', 'o'), ('ha', 've_'), ('m', 'y_'), ('m', 'a'), ('l', 'a'), ('s', 'e'), ('gh', 't_'), ('k', 'e_'), ('d', 'i'), ('s', 'o_'), ('th', 'e'), ('m', 'r_'), ('c', 'on'), ('ou', 'r_'), ('e', 'c'), ('a', 'b'), ('h', 'o'), ('t', 't'), ('p', 'o'), ('f', 'a'), ('q', 'u'), ('u', 'n'), ('a', 'g'), ('m', 'i'), ('a', 'c'), ('i', 't'), ('n', 'e'), ('hi', 'm_'), ('e', 't_'), ('f', 'i'), ('l', 'o'), ('w', 'ould_'), ('u', 'r'), ('c', 'ould_'), ('en', 't_'), ('a', 'y_'), ('no', 'w_'), ('e', 'x'), ('c', 'om'), ('p', 'p'), ('em', 'ma_'), ('be', 'en_'), ('s', 'p'), ('gh', 't'), ('d', 'o_'), ('m', 'o'), ('wi', 'll_'), ('r', 's_'), ('f', 'or'), ('an', 'y_'), ('b', 'y_'), ('m', 'rs_'), ('d', 'e'), ('i', 'd_'), ('the', 'y_'), ('f', 'rom_'), ('o', 'w'), ('w', 'ere_'), ('n', 'i'), ('k', 'ing_'), ('y', 'our_'), ('mu', 'st_'), ('d', 's_'), ('t', 'a'), ('p', 'er'), ('r', 'a'), ('whi', 'ch_'), ('mis', 's_'), ('i', 'f_'), ('u', 'e_'), ('sel', 'f_'), ('c', 'h'), ('en', 't'), ('b', 'o'), ('a', 's'), ('a', 'm_'), ('su', 'ch_'), ('f', 'u'), ('g', 'i'), ('i', 'r_'), ('mu', 'ch_'), ('on', 's_'), ('w', 'ell_'), ('p', 'ro'), ('w', 'or'), ('har', 'ri'), ('sa', 'id_'), ('w', 'e_'), ('d', 'y_'), ('y', 's_'), ('g', 'oo'), ('f', 'e'), ('t', 'ed_'), ('p', 'ar'), ('c', 'i'), ('e', 'very_'), ('w', 'est'), ('wh', 'en_'), ('a', 'f'), ('mo', 'st_'), ('s', 'hould_'), ('ow', 'n_'), ('r', 'y_'), ('litt', 'le_'), ('el', 't'), ('c', 'u'), ('v', 'i'), ('ni', 'ght'), ('goo', 'd_'), ('k', 'now_'), ('o', 'l'), ('k', 'night'), ('t', 's_'), ('knight', 'le'), ('harri', 'et_'), ('c', 'a'), ('r', 'u'), ('ti', 'on_'), ('o', 'f'), ('thin', 'k_'), ('o', 'p'), ('w', 'e'), ('the', 'ir_'), ('west', 'on_'), ('t', 'y_'), ('d', 'o'), ('en', 'd_'), ('ne', 'ver_'), ('f', 'ri'), ('be', 'ing_'), ('w', 'a'), ('i', 'm'), ('hou', 'se_'), ('g', 'o'), ('s', 'ome_'), ('v', 'ed_'), ('mi', 'ght_'), ('s', 'hall_'), ('li', 'ke_'), ('t', 'er_'), ('on', 'ly_'), ('a', 'd'), ('knightle', 'y_'), ('w', 'oo'), ('ha', 'pp'), ('k', 'ed_'), ('com', 'p'), ('ag', 'a'), ('it', 'e_'), ('woo', 'd'), ('g', 's_'), ('h', 'er'), ('g', 'e_'), ('i', 'r'), ('elt', 'on_'), ('j', 'u'), ('in', 't'), ('t', 'oo_'), ('o', 'b'), ('h', 'ear'), ('e', 'p'), ('qu', 'ite_'), ('g', 'reat_'), ('d', 'u'), ('se', 'e_'), ('e', 'v'), ('d', 'ay_'), ('j', 'ane_'), ('o', 'h_'), ('no', 'thing_'), ('u', 's_'), ('j', 'o'), ('be', 'fore_'), ('abou', 't_'), ('her', 'self_'), ('m', 'e'), ('b', 'le_'), ('h', 'e'), ('wood', 'house_'), ('g', 'u'), ('fu', 'l_'), ('ou', 't_'), ('t', 'ly_'), ('nes', 's_'), ('ch', 'ur'), ('wa', 'ys_'), ('fa', 'ir'), ('t', 'ur'), ('o', 'ther_'), ('l', 's_'), ('thou', 'ght_'), ('ec', 't_'), ('fair', 'fa'), ('chur', 'chi'), ('k', 'in'), ('in', 'de'), ('al', 'ways_'), ('d', 'a'), ('y', 'ing_'), ('s', 'oon_'), ('a', 'pp'), ('fir', 'st_'), ('sp', 'ea'), ('y', 'es_'), ('lor', 'd_'), ('f', 'ran'), ('s', 'or'), ('c', 'er'), ('ex', 'p'), ('y', 'oun'), ('aga', 'in_'), ('ma', 'ke_'), ('t', 'w'), ('l', 'u'), ('youn', 'g_'), ('fairfa', 'x_'), ('s', 'ome'), ('inde', 'ed_'), ('thou', 'gh_'), ('tw', 'o_'), ('fran', 'k_'), ('bo', 'dy_'), ('re', 'e_'), ('churchi', 'll_'), ('a', 'way_') ...
# Vocabulary after training: {'emma_': 751, 'by_': 696, 'jane_': 272, 'au sten_': 1, '1 8 1 6_': 1, 'volu me_': 4, 'i_': 3640, 'chapter_': 56, 'woodhouse_': 263, 'handsome_': 34, 'c lever_': 26, 'and_': 5823, 'ri ch_': 18, 'with_': 1528, 'a_': 3697, 'comfortable_': 34, 'home_': 134, 'happy_': 141, 'disposition_': 29, 'seemed_': 141, 'to_': 5943, 'unite_': 3, 'some_': 309, 'of_': 5030, 'the_': 6578, 'best_': 94, 'bles sin gs_': 6, 'existence_': 5, 'had_': 1669, 'li ved_': 25, 'nearly_': 14, 'twent y one_': 1, 'years_': 56, 'in_': 2672, 'world_': 101, 'very_': 1239, 'little_': 419, 'dist ress_': 21, 'or_': 601, 'vex_': 1, 'her_': 2546, 'she_': 2337, 'was_': 2487, 'youn gest_': 5, 'two_': 198, 'dau ghters_': 23, 'most_': 327, 'affec ti onate_': 9, 'in dul gent_': 1, 'father_': 226, 'consequence_': 30, 'sisters_': 20, 'marriage_': 40, 'been_': 760, 'mist ress_': 11, 'his_': 1479, 'house_': 93, 'from_': 663, 'early_': 41, 'peri od_': 18, 'mother_': 109, 'di ed_': 7, 'too_': 299, 'long_': 160, 'ago_': 28, 'for_': 1581, 'have_': 1333, 'more_': 561, 'than_': 416, 'an_': 535, 'in distinc t_': 1, 'rememb ran ce_': 11, 'cares ses_': 1, 'place_': 95, 'su pp lied_': 5, 'excellent_': 44, 'woman_': 123, 'as_': 1652, 'gover ness_': 8, 'who_': 347, 'fal len_': 10, 'short_': 72, 'affection_': 53, 'si x te en_': 9, 'miss_': 587, 'taylor_': 36, 'mr_': 1124, 'woodhouses_': 40, 'family_': 74, 'less_': 66, 'friend_': 172, 'fond_': 40, 'both_': 124, 'but_': 1539, 'particularly_': 45, 'between_': 73, 'them_': 499, 'it_': 2843, 'intimacy_': 21, 'even_': 131, 'before_': 266, 'c eased_': 6, 'hold_': 38, 'nominal_': 1, 'of fice_': 8, 'mil dness_': 1, 'temper_': 34, 'hardly_': 72, 'allowed_': 42, 'impose_': 1, 'any_': 673, 'restra int_': 3, 'shadow_': 4, 'au thority_': 6, 'being_': 369, 'now_': 401, 'passed_': 54, 'away_': 184, 'they_': 656, 'li ving_': 18, 'together_': 88, 'mu tually_': 3, 'attached_': 24, 'doing_': 44, 'just_': 163, 'what_': 728, 'li ked_': 15, 'high ly_': 25, 'este eming_': 1, 'tay lors_': 8, 'judgment_': 28, 'direc ted_': 6, 'chi ef ly_': 7, 'own_': 305, 'real_': 42, 'evils_': 10, 'indeed_': 197, 'emmas_': 77, 'situation_': 63, 'were_': 633, 'power_': 49, 'having_': 147, 'rather_': 145, 'much_': 517, 'way_': 160, 'think_': 391, 'well_': 426, 'herself_': 267, 'these_': 113, 'disadvan tages_': 1, 'which_': 603, 'th reatened_': 4, 'al lo y_': 3, 'many_': 159, 'enjo y ments_': 3, 'danger_': 34, 'however_': 124, 'at_': 1108, 'present_': 89, 'so_': 1149, 'un perc ei ved_': 2, 'that_': 2159, 'did_': 410, 'not_': 2457, 'means_': 48, 'ran k_': 10, 'mis fortunes_': 1, 'sor row_': 18, 'ca mea_': 1, 'gent le_': 25, 'sor row but_': 1, 'all_': 979, 'sha pe_': 11, 'disagreeable_': 18, 'consci ous nes smiss_': 1, 'married_': 48, 'lo ss_': 23, 'first_': 221, 'brought_': 59, 'gri ef_': 9, 'on_': 850, 'wed din g day_': 3, 'this_': 799, 'belo ved_': 8, 'sat_': 40, 'mour n ful_': 1, 'thought_': 236, 'continu an ce_': 2, 'wed ding_': 9, 'over_': 135, 'b ri depeople_': 1, 'gone_': 97, 'left_': 72, 'dine_': 15, 'no_': 834, 'pro spect_': 13, 'thir d_': 6, 'cheer_': 6, 'evening_': 97, 'composed_': 6, 'himself_': 137, 'sle ep_': 23, 'after_': 172, 'dinner_': 42, 'usual_': 50, 'then_': 300, 'only_': 333, 'sit_': 58, 'lost_': 36, 'event_': 22, 'every_': 444, 'promise_': 23, 'happiness_': 76, 'weston_': 382, 'man_': 261, 'unexcep ti onable_': 7, 'character_': 44, 'easy_': 27, 'fortune_': 41, 'su itable_': 4, 'age_': 31, 'pleasant_': 44, 'manners_': 53, 'there_': 605, 'satis faction_': 25, 'consi dering_': 20, 'self den ying_': 1, 'generous_': 7, 'friend ship_': 27, 'always_': 235, 'wished_': 46, 'promo ted_': 4, 'mat ch_': 27, 'b lack_': 13, 'mor nin gs_': 5, 'wor k_': 23, 'want_': 93, 'would_': 890, 'be_': 2181, 'felt_': 112, 'hour_': 74, 'day_': 188, 'recalled_': 2, 'past_': 25, 'kin d nes sthe_': 1, 'kindness_': 36, 'y ear s how_': 1, 'tau ght_': 9, 'how_': 440, 'played_': 8, 'five_': 38, 'ol d how_': 1, 'devo ted_': 5, 'powers_': 16, 'attach_': 5, 'a muse_': 8, ' ...
# Encoded: ['lowest', 'pichart_']
# Decoded: lowestpichart
