# %%
import nltk
from collections import Counter, defaultdict
from nltk.tokenize import word_tokenize
from nltk.corpus import gutenberg
nltk.download('punkt')
nltk.download('gutenberg')

def get_vocab(text):
    # Tokenize text using NLTK's word_tokenize, keeping original case
    words = word_tokenize(text)  # Using NLTK here - this is for initial vocabulary
    vocab = Counter(words)
    return {word: freq for word, freq in vocab.items()}

def get_stats(vocab):
    # Get frequency of adjacent symbol pairs (bigrams) in vocabulary
    pairs = defaultdict(int)
    for word, freq in vocab.items():
        symbols = word.split()
        for i in range(len(symbols) - 1):
            pairs[symbols[i], symbols[i+1]] += freq
    return pairs

def merge_vocab(pair, vocab):
    # Merge most frequent pair in all vocabulary words and update frequency
    new_vocab = {}
    bigram = ' '.join(pair)
    replacement = ''.join(pair)
    for word in vocab:
        new_word = word.replace(bigram, replacement)
        new_vocab[new_word] = vocab[word]
    return new_vocab

def preprocess_text(text):
    """Helper function to preprocess text similar to the class version"""
    # Split text into words (keeping punctuation as separate tokens)
    words = []
    current_word = ''
    
    for char in text:
        if char.isspace() or char in '.,!?;:()[]{}""\'':
            if current_word:
                words.append(current_word)
                current_word = ''
            if not char.isspace():  # Keep punctuation as separate tokens
                words.append(char)
        else:
            current_word += char
    if current_word:
        words.append(current_word)
    
    return ' '.join(words)

def encode(text, merges):
    """
    Encode text using learned BPE merges
    Args:
        text (str): Text to encode
        merges (list): List of merge pairs in order of learned priority
    Returns:
        list: List of encoded tokens
    """
    processed_text = preprocess_text(text)
    result = []
    
    # Pre-compute merge dictionary for O(1) lookup
    merge_dict = {}
    for pair in merges:
        merge_dict[" ".join(pair)] = "".join(pair)
    
    for word in processed_text.split():
        current = " ".join(list(word))
        
        # Keep trying merges until no changes can be made
        while True:
            # Track if any merge was applied
            merged = False
            
            # Find all possible merges in the current state
            parts = current.split()
            for i in range(len(parts) - 1):
                bigram = f"{parts[i]} {parts[i+1]}"
                if bigram in merge_dict:
                    # Apply the merge
                    merged_token = merge_dict[bigram]
                    current = current.replace(bigram, merged_token, 1)
                    merged = True
                    break  # Start over with new token state
                    
            if not merged:  # No more merges possible
                break
                
        result.append(current.replace(" ", ""))
    
    return result

def decode(tokens):
    """
    Decode BPE tokens back to text
    Args:
        tokens (list): List of encoded tokens
    Returns:
        str: Decoded text
    """
    return ' '.join(tokens)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/dhruvgorasiya/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /Users/dhruvgorasiya/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!

# %%
if __name__ == "__main__":
    # Training books
    book1 = gutenberg.raw("austen-emma.txt")
    book2 = gutenberg.raw("blake-poems.txt") 
    book3 = gutenberg.raw("shakespeare-hamlet.txt")
    
    # Combine training texts
    training_text = book1 + " " + book2 + " " + book3
    
    # Test books
    test_book1 = gutenberg.raw("shakespeare-caesar.txt")
    test_book2 = gutenberg.raw("carroll-alice.txt")
    test_book3 = gutenberg.raw("chesterton-ball.txt")
    
    # Create reference tokenizations using NLTK
    reference_tokenizations = {
        'shakespeare-caesar': word_tokenize(test_book1),
        'carroll-alice': word_tokenize(test_book2),
        'chesterton-ball': word_tokenize(test_book3)
    }
    
    # Initialize vocabulary with character-level splits
    vocab = get_vocab(training_text)
    vocab = {' '.join(word): freq for word, freq in vocab.items()}
    print("Initial vocabulary size:", len(vocab))

    # Number of BPE merges to perform
    num_merges = 100000

    # Train BPE and store merges
    merges = []
    for i in range(num_merges):
        pairs = get_stats(vocab)
        if not pairs:
            break
        best_pair = max(pairs, key=pairs.get)
        vocab = merge_vocab(best_pair, vocab)
        merges.append(best_pair)

    print("\nTokenization Comparison:")
    print("-" * 50)

    # Test on each book
    for book_name, ref_tokens in reference_tokenizations.items():
        test_book = gutenberg.raw(f"{book_name}.txt")
        bpe_tokens = encode(test_book, merges)
        
        # Calculate metrics
        bpe_vocab = set(bpe_tokens)
        ref_vocab = set(ref_tokens)
        
        print(ref_vocab)
        print(bpe_vocab)
        
        # Basic statistics
        ref_vocab_size = len(ref_vocab)
        bpe_vocab_size = len(bpe_vocab)
        total_ref_tokens = len(ref_tokens)
        total_bpe_tokens = len(bpe_tokens)
        
        # Calculate token lengths
        ref_avg_len = sum(len(token) for token in ref_tokens) / total_ref_tokens
        bpe_avg_len = sum(len(token) for token in bpe_tokens) / total_bpe_tokens
        
        # Calculate matching metrics
        true_positives = len(ref_vocab & bpe_vocab)
        false_positives = len(bpe_vocab - ref_vocab)
        false_negatives = len(ref_vocab - bpe_vocab)
        
        # Calculate token-level matches (not just vocabulary matches)
        # correct_tokens = sum(1 for ref, bpe in zip(ref_tokens, bpe_tokens) if ref == bpe)
        correct_tokens = 0
        for i in bpe_tokens:
            if i in ref_tokens:
                correct_tokens += 1
        accuracy = (correct_tokens / total_ref_tokens) * 100 if total_ref_tokens > 0 else 0
        
        # Calculate precision, recall, F1
        precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
        recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        
        # Calculate Jaccard similarity
        jaccard = len(ref_vocab & bpe_vocab) / len(ref_vocab | bpe_vocab) if len(ref_vocab | bpe_vocab) > 0 else 0
        
        # Calculate accuracy and coverage
        # accuracy = (true_positives / total_ref_tokens) * 100 if total_ref_tokens > 0 else 0
        coverage = (len(ref_vocab & bpe_vocab) / len(ref_vocab)) * 100 if len(ref_vocab) > 0 else 0
        
        print(f"\nResults for {book_name}:")
        print(f"Reference vocabulary size: {ref_vocab_size}")
        print(f"BPE vocabulary size: {bpe_vocab_size}")
        print(f"Reference avg token length: {ref_avg_len:.2f}")
        print(f"BPE avg token length: {bpe_avg_len:.2f}")
        print(f"Total reference tokens: {total_ref_tokens}")
        print(f"Total BPE tokens: {total_bpe_tokens}")
        print(f"Tokenization accuracy: {accuracy:.2f}%")
        print(f"Tokenization coverage: {coverage:.2f}%")
        print(f"Precision: {precision:.2f}")
        print(f"Recall: {recall:.2f}")
        print(f"F1 score: {f1_score:.2f}")
        print(f"Jaccard similarity: {jaccard:.2f}")
        print(f"True positives: {true_positives}")
        print(f"False positives: {false_positives}")
        print(f"False negatives: {false_negatives}")
        print("-" * 50)
# Out:
# Initial vocabulary size: 13244
#
# Tokenization Comparison:
# --------------------------------------------------
# {'Mes', 'Banquetting', 'doe', 'Gaue', 'darknesse', 'waste', 'burne', 'immediate', 'against', 'deseru', "sland'rous", 'voyd', 'credit', 'Listen', 'Therefore', 'thinke', 'damned', 'knock', 'meate', 'Are', 'Point', 'Nothing', 'bloodie', 'silence', 'heauy', 'howre', 'Ladder', 'fresh', 'saue', 'Powers', 'Courage', 'Thunder', 'refresht', 'Companies', 'A', 'lowly', 'Lupercall', 'without', 'immortall', 'One', 'Vs', 'higher', 'seal', 'driues', 'begins', 'Councell', 'Mechanicall', 'warning', 'Counsels', 'Haile', 'honors', 'Villager', 'Tharsus', 'Dost', 'matter', 'vs.', 'strife', 'spurne', 'people', 'first', 'Coronets', 'auoyded', 'Hoping', 'Peace', 'doore', 'peace', 'Emulation', 'Slaues', 'People', 'flye', 'angry', 'thither', 'arriu', 'heape', 'other', 'Caius', 'end', 'beware', 'Your', 'Countrey', 'surest', 'fat', 'begge', 'Dreames', 'Coffers', 'Tide', 'Vow', 'Lye', 'Honest', 'else', 'bouge', 'embrace', 'Doublet', 'determined', 'swore', 'pittifull', 'loue', 'Power', 'Wherein', 'meeke', 'offended', 'strikes', 'Rogues', 'Canst', 'thank', 'Neuer', 'owne', 'Addition', 'Field', "'Tis", 'below', 'Flowers', 'Tapers', 'Strawes', 'Farewell', 'Immortall', 'Cogitations', '2', 'Horses', 'stop', 'spare', 'warnings', 'respect', 'threw', 'Crowne', 'wash.', 'Hats', 'drawing', 'knot', 'alas', 'battailes', 'Iron', 'Greeke', 'byrth', 'beyond', 'Wiues', 'Orchard', 'Armes', 'need', 'Window', 'recount', 'Vnicornes', 'Greefes', 'augmented', 'drowsily', 'thoughts', 'answered', 'Dogges', 'Starres', 'stirr', 'aueng', 'amisse', 'wine', 'being', 'whizzing', 'Ruines', "Whil'st", 'Fires', 'liable', 'Chimney', 'Leape', 'forgaue', 'liue-long', 'Women', 'forth', 'annoy', 'names', 'morning', "cry'de", 'degrees', 'Arme', 'Tune', 'inroll', 'brutish', 'Childe', 'push', 'eare', 'disclos', 'Skie', 'acting', 'instantly', 'Lucillius', 'Parthia', 'Profession', 'married', 'Wherefore', 'ran', 'Pretors', 'Loe', 'enlarge', 'Peoples', 'Triumphes', 'about', 'Ile', "displeas'd", 'North', 'Heart', 'Musing', 'pitteous', 'Olympus', 'why', 'for', 'Rocke', 'among', 'Fast', 'noyse', 'taking', 'shooes', 'teeth', 'far', 'bonds', 'Doe', 'dishonourable', 'fasten', 'Performance', 'Robbers', 'insisted', 'Study', 'acquainted', 'Anchyses', 'ears', 'melting', 'Falles', 'wounded', 'deriu', 'a-foot', 'Sheath', 'vanishest', 'Serpents', 'Recounts', 'Counters', 'Ate', 'deepe', 'quarter', 'Vndeseruers', 'Storme', 'side', 'earnes', 'whether', 'Tempt', 'Clamors', 'slept', 'Ple', 'Fearing', 'intended', 'benefit', 'ouer-earnest', 'bent', 'stirre', 'swoonded', 'Alchymie', 'Conspirators', 'may', 'nimblenesse', 'loosing', 'booke', 'wilt', 'Vtterance', 'Pulpits', "i'th", 'appearing', 'Conditions', 'Motiues', 'remaine', 'affrighted', 'much', 'hazard', 'Prouender', 'thanke', 'curse', 'waues', 'Bloods', 'Sunne', 'current', 'cancell', 'too', 'South', 'selfe', 'Surgeon', 'fawne', 'newes', 'Ambitions', 'hurtled', 'greeting', 'obserue', 'Angel', 'Maiesticke', 'Spirit', 'bathe', 'crowd', 'thaw', 'Lustre', 'nice', 'thirtie', 'sate', 'rather', 'of', 'though', 'Yet', 'speechlesse', 'bath', 'Miseries', 'Passion', 'Rauens', 'euen', 'shew', 'tag-ragge', 'go', 'here', 'consent', 'Faith', 'rent', 'heard', 'rage', 'force', 'Eyes', 'Willes', 'rime', 'feare', 'chafing', 'flearing', 'Reuels', 'Shout', 'ore-watch', 'dreamt', "Is't", 'Faculties', 'leads', 'recreate', 'gentlenesse', 'comfort', 'deceitfull', 'Kites', 'Withall', 'off', 'Enioy', 'Enuious', 'apply', 'turnes', 'knockes', 'ascended', '1.Sold', 'Horsemen', 'Be', 'Constancie', 'disperse', 'Calphurnia', 'ranging', 'friend', 'Nature', 'strength', 'faine', 'train', 'rash', 'We', 'slip', 'piece', 'Come', '!', 'neede', 'vttermost', 'pre-formed', 'proclaime', 'Dwell', 'borne', 'least', 'carue', 'Know', 'opens', 'marry', 'vanished', 'brauery', 'appoint', 'Gorging', 'expect', "know'st", 'Bosome', 'Make', 'Shaking', 'tydings', 'grug', 'prethee', 'Eagles', 'dis-ioynes', 'Cushions', 'lodge', 'Bondman', 'fret', 'spoyle', 'wise', 'feast', 'Tyber', 'trembled', 'thine', 'Ceremony', 'choose', ...
# {'new_', 'Crowne_', 'Aboue_', 'fortunate_', 'voyces_', 'couert_', 'Diuell_', 'sighing_', 'contented_', 'Toyles_', 'Song_', 'mens_', 'hony-heauy-Dew_', 'Thorow_', '!_', 'Lines_', 'braue_', 'sober_', 'sounds_', 'within_', 'bosome_', 'Assembly_', 'makes_', 'pluck_', 'hatefull_', 'seest_', 'answer_', 'Antonies_', 'set_', 'returning_', 'cuts_', 'Lippes_', 'runne_', 'piece_', 'mans_', 'such_', 'opening_', '(_', 'left_', 'Faction_', 'Dardanius_', 'hideous_', 'we_', 'scratch_', 'runnes_', 'Coarse_', 'dismisse_', 'has_', 'Bondmen_', 'School-boy_', 'lose_', 'inflame_', 'wounded_', 'ouer_', 'dangers_', 'mischieuous_', 'maske_', 'giues_', 'quality_', 'arriu_', 'naked_', 'hill_', 'charme_', 'Battlements_', 'content_', 'wife_', 'flourish_', 'ioyn_', 'findes_', 'sorry_', 'affection_', 'Leafe_', 'Horsses_', 'sham_', 'spectacle_', 'seen_', 'chide_', 'Make_', 'Ague_', 'proscription_', 'disgest_', 'iudgement_', 'againe_', 'Commoners_', 'Haile_', 'Fountaine_', 'naughty_', 'marr_', 'thy_', 'search_', 'lodge_', 'Might_', 'terror_', 'praising_', 'toucht_', 'Poore_', 'opens_', 'Tyranny_', 'keepes_', 'will_', 'made_', 'incompast_', 'speake_', 'pul_', 'Coward_', 'begge_', 'perils_', 'Dreame_', 'making_', 'Holyday_', 'him_', 'weare_', 'Through_', 'Drachmaes_', 'motion_', 'Royall_', 'gone_', 'Romans_', 'peepe_', 'dimme_', 'Ring_', 'Portia_', 'Citizen_', 'further_', 'perswasion_', 'away_', 'walke_', 'make_', 'cride_', '-_', 'Sham_', 'Descend_', 'History_', 'Kingly_', 'Verses_', 'faults_', 'Sardis_', 'ingag_', 'chides_', 'Shrunke_', 'haste_', 'Reason_', 'foolish_', 'befall_', 'Heard_', 'desir_', 'Rogues_', 'Is_', 'Kingdome_', 'Seeing_', 'mightie_', 'wash_', 'entreated_', 'case_', 'affrighted_', 'Theatre_', 'leysure_', 'Action_', 'Secundus_', 'Wil_', 'Ingratitude_', 'Th_', 'sweet_', 'Measure_', 'Leaue_', 'Plucking_', 'drowsily_', 'pay_', 'being_', 'Writings_', 'hast_', 'cruell_', 'Bosome_', 'whizzing_', 'vtter_', 'himselfe_', 'Chaire_', 'Mechanicall_', 'Cares_', 'seem_', 'speech_', 'vnkindnesse_', 'watch_', 'Sooth-sayer_', 'Bookes_', 'fearefulnesse_', 'Orator_', 'Chasticement_', 'beyond_', 'seemes_', 'vntouch_', 'And_', 'kinde_', 'breefely_', 'dip_', 'day-_', 'Tharsus_', 'Conceptions_', 'What_', 'Transformed_', 'dead_', 'twenty_', 'fooles_', 'Courage_', 'Seek_', 'concluded_', 'sound_', 'kneele_', 'repose_', 'lost_', 'vanishest_', 'early_', 'Throat_', 'Flourish_', 'ayme_', 'Dish_', 'receiue_', 'needs_', 'Straine_', 'mourn_', 'swet_', 'doo_', 'Friend_', 'Epicurus_', 'Cauerne_', 'Octauio_', 'roares_', 'debt_', 'Men_', 'Tooke_', 'suppe_', 'With_', 'sought_', 'd_', 'Infants_', 'Mender_', 'haires_', 'moe_', 'attempt_', 'fare_', 'seat_', 'Profession_', 'rabblement_', 'darknesse_', 'drop_', 'Horse_', 'Bending_', '._', 'heart_', 'throwes_', 'Senses_', 'Legions_', 'witnesse_', 'smatch_', 'Ant_', 'incorporate_', 'dy_', 'Braue_', 'better_', 'When_', 'Incenses_', 'vaunting_', 'driues_', 'liued_', 'Passe_', 'Be_', 'paid_', 'Rome_', 'cooling_', 'height_', 'pledge_', 'groaning_', 'Flint_', 'Tertius_', 'wake_', 'Mischeefe_', 'sawcy_', 'light_', 'about_', 'sad_', 'respect_', 'crept_', 'greefes_', 'into_', 'Caska_', 'bouge_', 'belou_', 'Twere_', 'reflection_', 'hope_', 'fifteene_', 'Madam_', 'Walles_', 'grant_', 'iust_', 'Mid-night_', 'Obiects_', 'Study_', 'Truely_', 'foot_', 'Cal_', 'seru_', 'mourning_', 'threats_', 'Hell_', 'nod_', 'chafing_', 'Enuy_', 'patient_', 'Round_', 'Yes_', 'insisted_', 'Farre_', 'hinder_', 'yeare_', 'Note-booke_', 'winne_', 'Cannot_', 'dis-ioynes_', 'counsell_', 'with_', 'intrailes_', 'choak_', 'calculate_', 'on_', 'Woe_', 'Fare_', 'wrangle_', 'bury_', 'Treasure_', 'hand_', 'mooue_', 'mood_', ';_', 'Honorable_', 'past_', 'Summers_', 'foule_', 'disclose_', 'Letters_', 'Glasses_', 'Murellus_', 'Better_', 'Next_', 'yoaked_', 'Smiles_', 'Marcus_', 'Honor_', 'bent_', 'Basis_', 'quarter_', 'hedge_', 'course_', 'Appetite_', 'But_', 'ours_', 'Vessell_', 'Tune_', 'lay_', 'stal_', 'Stand_', 'enuy_', 'Begin_', 'Fire_', 'Take_', 'vexeth_', 'spot_', 'Linkes_',  ...
#
# Results for shakespeare-caesar:
# Reference vocabulary size: 3610
# BPE vocabulary size: 3580
# Reference avg token length: 3.52
# BPE avg token length: 4.46
# Total reference tokens: 25251
# Total BPE tokens: 25689
# Tokenization accuracy: 0.00%
# Tokenization coverage: 0.00%
# Precision: 0.00
# Recall: 0.00
# F1 score: 0.00
# Jaccard similarity: 0.00
# True positives: 0
# False positives: 3580
# False negatives: 3610
# --------------------------------------------------
# {"'UNimportant", 'globe', 'alternately', 'waste', 'immediate', 'cook', 'against', 'pigs', 'Therefore', 'generally', 'coast', 'harm', 'INSIDE', 'consultation', 'knock', 'quiet', "'Off", 'silence', 'Kings', 'Improve', 'hoarse', 'entrance', 'cards', 'surprise', 'except', 'housemaid', 'A', 'received', 'stool', 'without', 'couples', 'One', 'deep', 'joined', 'panting', 'apples', 'begins', 'loudly', 'warning', 'glass', 'spectacles', 'adjourn', 'matter', 'music', 'people', 'first', 'despair', 'THEN', 'doorway', 'nursing', '_I_', 'brave', 'angry', 'started', 'other', 'skimming', 'end', 'flock', 'Poor', 'fat', "'She", 'tears', 'trusts', 'HAVE', 'dropped', 'impertinent', 'else', 'ornamented', 'sand', 'straightening', 'lowing', 'slightest', 'account', 'fan', 'absurd', 'offended', "'which", 'happening', 'lobster', 'bowed', 'treacle-well', 'thank', 'balls', 'meant', "I'm", 'below', "'Everything", "'Curiouser", 'piteous', 'ones', 'even', 'whistle', 'stop', 'saucepan', 'onions', 'respect', 'threw', 'eels', "'Mouse", 'Mad', 'distance', 'untwist', 'engaged', 'knot', 'drawing', 'wildly', 'explanation', 'alas', 'linked', "'Hold", 'overcome', 'dance', 'finding', 'chains', 'roast', 'lasted', 'need', "'moral", 'Lastly', 'undo', 'shorter', 'shelves', 'Nile', "'No", 'answered', 'maybe', 'Heads', 'thoughts', "'SHE", 'nowhere', 'engraved', 'Lacie', 'pronounced', 'beloved', 'wine', 'bird', 'bat', 'being', "'until", "'Keep", 'awfully', 'puffed', 'underneath', "N'T", 'carried', 'annoy', 'sheep-bells', 'names', 'morning', 'prevent', "'the", 'WASHING', 'push', 'neck', 'doubled-up', 'hurt', 'airs', 'London', 'interrupting', 'position', 'brother', 'wider', 'instantly', 'longer', 'rattle', 'grinned', 'ran', 'corner', 'earls', 'half', 'FATHER', 'lark', 'purple', 'about', 'belong', 'hoped', 'LESS', 'tremulous', 'queerest', 'authority', 'lifted', "'Oh", 'telling', 'IN', 'leaves', 'why', 'for', 'among', 'help', 'used', 'fur', 'shore', 'cunning', 'THIS', "'Stolen", 'taking', 'teeth', "'jury-men", 'denial', 'far', 'unfortunate', 'station', 'THEY', 'thump', 'eats', 'catch', 'upset', 'MILE', 'ears', 'hint', 'turkey', 'Beautiful', 'askance', 'WHATEVER', 'invited', 'dates', 'rope', 'whether', 'side', 'key', 'oneself', 'Tea-Party', 'trembling', 'bent', "'are", 'walrus', "haven't", 'personal', 'THAN', 'branches', 'cartwheels', 'may', 'teacup', 'patted', 'appearing', 'alarmed', 'much', 'Grammar', 'jury', 'courage', 'too', 'digging', 'nurse', "'Explain", 'subject', 'master', 'archbishop', 'letters', 'addressing', 'hall', 'passage', 'boots', "'In", 'crowd', 'nice', 'pinched', 'kind', 'rather', 'croqueted', 'of', 'though', 'important', 'short', 'happens', 'Yet', 'snail', 'hurried', 'getting', 'rubbed', 'opposite', 'here', 'go', 'barking', 'wings', 'RABBIT', "'on", "'Fury", 'heard', 'kick', "'Sh", 'cutting', 'English', 'dark', "can't", 'arguments', "'Two", 'punished', 'lessons', 'king', "'Why", 'moved', 'commotion', 'plan', "'three", 'clearly', 'yer', 'bawled', 'scolded', 'comfort', 'Tarts', 'Prizes', 'Crab', 'Queens', 'off', "'if", 'looked', "'let", "'Leave", 'flying', 'provoking', 'holding', 'mischief', 'gay', 'quarrel', '*', 'Be', 'downwards', 'pieces', 'Canary', "'For", 'tossing', 'painting', 'strength', 'failure', 'spite', 'friend', 'driest', 'lock', 'telescopes', 'We', 'Ma', 'Come', 'Still', '!', 'occasionally', 'picked', 'piece', 'least', 'puppy', "'But", 'never', 'disobey', 'signifies', 'vanished', 'idiotic', 'guessed', 'instance', 'scale', 'outside', 'Mystery', 'Mock', "'At", 'idea', 'wise', 'YOU', 'trembled', 'boon', 'turns', 'OLD', 'calmly', 'cause', 'William', 'pine-apple', 'present', 'doze', 'bound', 'murdering', 'hand', 'pink', 'mournfully', 'bill', 'reading', 'killing', 'slate-pencil', 'returned', 'stretching', 'eagerly', "'Only", 'desperate', 'forgot', 'Silence', 'Edwin', 'inclined', 'shrieks', 'variations', 'smallest', 'opinion', "'Everybody", 'pencil', 'Two', 'sneeze', 'pepper-box', 'BEST', 'minute', 'repeat', 'move', 'considered', 'baby', 'everybody', 'hot-te ...
# {'new_', 'can--_', 'Nile_', 'save_', 'nibbled_', 'sighing_', 'sense_', 'rudeness_', 'affectionately_', 'shutting_', '--SAID_', 'anxiously_', 'judging_', 'complained_', 'Edgar_', '!_', 'school_', 'submitted_', 'adventures--beginning_', 'reeds--the_', 'EAT_', 'sounds_', 'spite_', 'footmen_', 'Always_', 'within_', 'Northumbria--_', 'beak--_', 'makes_', 'pretty_', 'clubs_', 'reply_', 'Only_', 'answer_', 'set_', 'returning_', 'sobbing_', 'couples_', 'addressed_', 'piece_', 'such_', 'hate--C_', 'opening_', 'yet--Oh_', '(_', 'hoping_', 'left_', 'digging_', 'conversation_', 'under_', 'we_', 'know--No_', 'trotting_', 'entrance_', 'beheaded_', 'contemptuously_', 'finish_', 'roared_', 'music_', 'vague_', 'lately_', 'has_', 'IN_', 'extraordinary_', 'delight_', 'shepherd_', 'Gryphon_', 'pack_', 'lose_', 'years_', 'expression_', 'thump_', 'MARMALADE_', 'happen_', 'wandering_', 'content_', 'wife_', 'quicker_', 'subdued_', 'Fourteenth_', 'sorry_', 'cauldron_', 'called_', 'feathers_', 'Heads_', 'sudden_', 'Dodo_', 'you--all_', 'seen_', 'hurried_', 'partner_', 'ALICE_', 'boxed_', 'Sends_', 'us_', 'brushing_', 'flung_', 'royal_', 'line_', 'SAID_', 'furious_', 'terrier_', 'tail_', 'search_', 'pig-baby_', 'railway_', 'terror_', 'offend_', 'roses_', 'weak_', 'will_', 'made_', 'Dinah_', '--Mystery_', 'drew_', 'Turtle_', 'loudly_', 'making_', 'birds_', 'him_', 'dipped_', 'gone_', 'FATHER_', 'BOOTS_', 'used_', 'belong_', 'further_', 'written_', 'away_', 'thirteen_', 'ME_', 'make_', 'IS_', 'shiny_', 'accident_', 'chanced_', 'thatched_', 'wildly_', 'coward_', 'lobster_', 'distance--but_', 'procession_', 'axes_', 'foolish_', 'remembered_', 'steady_', 'shriek_', 'enormous_', 'e--e--evening_', 'haste_', 'plates_', 'evidence_', 'Is_', 'fig_', 'leaving_', 'wash_', 'll_', 'wherever_', 'tears_', 'case_', 'chief_', 'bowed_', 'advise_', 'hatching_', 'Pig_', 'possible_', 'France--_', 'being_', 'Off--_', 'venture_', 'child-life_', 'size_', 'to-night_', 'conger-eel_', 'fountains_', 'usurpation_', 'delightful_', 'dog_', 'used--and_', 'skimming_', 'XII_', 'whispers_', 'sorrowful_', 'watch_', 'seem_', 'speech_', 'graceful_', 'regular_', 'serpents_', 'annoyed_', 'pencil_', 'green_', 'splashed_', 'THESE_', 'forgetting_', 'fellows_', 'And_', 'violence_', 'squeaking_', 'glaring_', 'shade_', 'pleaded_', 'fifth_', 'sky-rocket_', 'longed_', 'What_', 'twenty_', 'dead_', 'trials_', 'concluded_', 'dish_', 'sound_', 'lost_', 'drunk_', 'readily_', 'teacup_', 'needs_', 'teases_', 'bats_', 'middle_', 'Australia_', 'laughed_', 'telling_', 'YOUR_', 'fading_', 'swimming_', 'savage_', 'quarrelled_', 'kills_', 'promising_', 'rush_', 'With_', 'LL_', 'd_', 'fifteen_', 'slates_', 'it--_', 'attempt_', 'DOTH_', 'producing_', 'figure_', 'hardly_', 'drop_', 'dispute_', '._', 'heart_', '--but_', 'grinned_', 'however_', 'top_', 'wandered_', 'gardeners_', 'drowned_', 'instance_', 'curtain_', 'dreaming_', 'awfully_', 'When_', 'better_', 'carrying_', 'Uglification_', 'legs_', 'kneel_', 'contempt_', 'water-well_', 'meat_', 'air_', 'general_', 'Be_', 'sheep-bells_', 'Rome_', 'height_', 'Hadn_', 'stingy_', 'just_', 'cats_', 'howled_', 'linked_', 'about_', 'brightened_', 'been_', 'sad_', 'stamping_', 'crept_', 'respect_', 'crocodile_', 'Northumbria_', 'into_', 'knelt_', 'wasting_', 'PLENTY_', 'pink_', 'again_', 'tiptoe_', 'hope_', 'grant_', 'nicely_', '*_', 'foot_', 'THIS_', 'hopeful_', 'snail_', 'curiouser_', 'Yes_', 'conversations_', 'AND_', 'porpoise_', 'flavour_', 'with_', 'spoke--fancy_', 'camomile_', 'on_', 'corners_', 'grown_', 'Adventures_', 'hand_', 'other--Bill_', ';_', 'pleasant_', 'letter_', 'variations_', 'past_', 'pretexts_', 'beautify_', 'Next_', 'HOW_', 'Just_', 'faster_', 'bent_', 'learned_', 'hedge_', 'rising_', 'course_', 'managed_', '--That_', 'But_', 'whiskers_', 'hurriedly_', 'lay_', 'Stand_', 'pepper_', 'nervous_', 'humbly_', 'vegetable_', 'couple_', 'Collar_', 'Take_', 'Begin_', 'earls_', 'spot_', 'Mercia_', 'truthful_', 'treated_', 'lap_', 'jury-box_', 'whiles_', 'fixed_', 'den ...
#
# Results for carroll-alice:
# Reference vocabulary size: 3184
# BPE vocabulary size: 3148
# Reference avg token length: 3.47
# BPE avg token length: 4.34
# Total reference tokens: 33494
# Total BPE tokens: 34728
# Tokenization accuracy: 0.00%
# Tokenization coverage: 0.00%
# Precision: 0.00
# Recall: 0.00
# F1 score: 0.00
# Jaccard similarity: 0.00
# True positives: 0
# False positives: 3148
# False negatives: 3184
# --------------------------------------------------
# {'articles', 'parties', 'globe', 'record', 'Golden', 'smelt', 'unexpected', 'downstairs', 'void', 'nail', 'including', 'quiet', 'lurching', 'applied', 'prickly', 'swing', 'cards', 'counties', 'A', 'reviled', 'concealed', 'agnostics', 'cellars', 'similarity', 'tunnels', 'Information', 'panting', 'begins', 'spectacles', 'county', 'Bent', 'blowing', 'parched', 'striking', 'modification', 'Money', 'People', 'hammer', 'peasants', 'lunch', 'priest', 'organizing', 'Russell', 'forgive', 'Poor', 'tears', 'turf', 'hare', 'overwhelming', 'Anyhow', 'gate-keepers', 'Transvaal', 'Catherine', 'gentleman', 'Nonsense', 'recognize', 'profligate', 'mirror', 'stunted', 'ungrateful', 'Beauchamp', 'careless', 'rectangular', 'encircling', 'devoid', 'unity', 'ones', 'lead', '2', 'respect', 'threw', 'cogency', 'dragon', 'bustle', 'singly', 'linked', 'arrogant', 'princes', 'discovering', 'sailing', 'block', 'barbarous', 'damning', 'habitable', 'need', 'horse-hoof', 'irrelevantly', 'Nominalism', 'impecunious', 'undo', 'walls', 'fragments', 'thoughts', 'shelves', 'gambling', 'researches', 'arrangements', 'irrelevant', 'pronounced', 'bird', 'eye-glasses', 'awfully', 'scrambled', 'craven', 'murmured', 'horrible', 'hullo', 'prevent', 'push', 'Nietzsche', 'hurt', 'varnished', 'Gardens', 'interrupting', 'Morrice', 'littered', 'shipwrecked', 'grinned', 'falcon', 'anonymous', 'about', 'liquid', 'North', 'harshly', 'unworthy', 'Albany', 'for', 'cunning', 'Have', 'spoil', 'unholy', 'ragging', 'connected', 'unfortunate', 'enthusiasm', 'vulgarity', 'grief', 'Houses', 'passages', 'Scotchman', 'Indiana', 'mentor', 'gathering', 'insisted', 'innocent', 'quarter', 'rope', 'whether', 'swerving', 'vividly', 'rhyme', 'drawl', 'breathing', 'swinging', 'subscription', 'branches', 'divinity', 'ghastly', 'forming', 'tavern', 'projecting', 'Jonah', 'portly', 'boats', 'surrender', 'mistaken', 'greeting', 'scoot', 'uncles', 'half-embarrassed', 'letters', 'Selsey', 'lightened', 'humming', 'mismanagement', 'kind', 'brute', 'short', 'variety', 'parade', 'lightly', 'getting', 'tallest', 'announcing', 'go', 'here', 'jolly', 'rent', 'unembarrassed', 'red-brown', 'Rapid', 'exhilarating', 'cutting', "can't", 'PHILOSOPHER', 'employ', 'convinced', 'ruler', 'unclean', 'deserted', 'momentary', 'pulsation', 'adamantine', 'desolate', 'related', 'gain', 'woods', 'summer-house-looking', 'holding', 'thinks', 'apply', 'gay', 'shone', 'bodily', 'prosperous', 'industrious', 'tossing', 'overtake', 'vista', 'interruption', 'corrections', 'nature-worshipping', 'star-shattering', 'vanished', 'PEACE', 'Beg', 'slatelike', 'marries', 'cloven', 'Westminster', 'Make', 'climbing', 'windowed', "isn't", 'inimical', 'turns', 'OLD', 'cause', 'colour', 'County', 'ungenerous', 'courteous', 'en', 'topmost', 'Defects', 'stricken', 'egotistic', 'bill', 'duellists', 'grim', 'devotee', 'thou', 'forgot', 'heights', 'cowardice', 'inclined', 'psychological', 'licenses', 'development', 'decorated', 'fanatic', 'repeat', 'minute', 'ducked', 'move', 'housekeeper', 'big', 'Elijah', 'ornament', 'everybody', 'silk', 'praising', 'slay', 'others', 'weakening', 'sceptic', 'letter', 'cornfield', 'elbow', 'spoils', 'tawny', 'decorously', 'strong', 'scorching', 'instantaneously', 'Bradlaugh', 'arise', 'mysticism', 'impressive', 'missing', 'philosophical', 'desired', 'litter', 'narrowed', 'conditions', 'viewless', 'dyed', 'rationalists', 'mix', 'digression', ',', 'signified', 'alarm', 'tended', 'joining', 'supernaturalism', 'bring', 'pessimist', 'Heard', 'squalid', 'good-humoured', 'botanical', 'dust', 'great', 'boomerang', 'notes', 'such', 'distanced', "Kruger's", 'spring', 'uncontrollable', 'massacre', 'environment', 'senses', 'insecurely', 'solution', 'dying', 'inserted', 'amiability', 'islanded', 'bookcase', 'famous', 'bubble', 'sacrifice', 'board', 'oblique', 'clashed', 'villagers', 'Parthenon', 'stroke', 'wrench', 'teach', 'mystic', 'Londoner', 'new', 'yours', 'Against', 'Loup', 'could', 'cataract', 'yelled', 'sloped', 'dwarfish', ...
# {'wind-swung_', 'save_', 'jewel_', 'meditation_', 'paradoxical_', 'sense_', 'judgement_', 'XVIII_', 'c_', 'waveringly_', 'unclean_', 'Fortunately_', 'cliffs_', 'falls_', 'TURNBULL_', 'barbaric_', 'sounds_', 'sober_', 'broodingly_', 'alternatively_', 'makes_', 'reply_', 'driving_', 'Culloden_', 'forty-eight_', 'imaginative_', 'self-submission_', 'maniacs_', 'suspicious_', 'addressed_', '(_', 'heroes_', 'invoked_', 'music_', 'primitive_', 'shocked_', 'spruce_', 'vitality_', 'rowed_', 'armies_', 'Gotham_', 'lately_', 'IN_', 'cords_', 'bloodshed_', 'prop_', 'climbed_', 'provisions_', 'primordial_', 'breakwater_', 'naked_', 'sardines_', 'wastes_', 'fissure_', 'cultured_', 'awakening_', 'signals_', 'brute_', 'Dr_', 'blocked_', 'us_', 'flung_', 'thy_', 'lot_', 'lodge_', 'offend_', 'unlike_', 'roses_', 'enthusiasm_', 'seaweed--evidently_', 'drew_', 'copied_', 'priests_', 'bits_', 'grumbling_', 'Barrès_', 'dipped_', 'due_', 'briefest_', 'defiance_', 'gone_', 'Romans_', 'fatigue_', 'Sidney_', 'used_', 'apartment_', 'haze_', 'you--you_', 'frigid_', 'IS_', 'strict_', 'Pah_', 'smooth_', 'parallels_', 'shallow_', 'estimate_', 'uncovered_', 'United_', 'enclosure_', 'long-pointed_', 'attracted_', 'hart@pobox_', 'precipice_', 'cruel_', 'ignored_', 'objects_', 'a--deity_', 'mud_', 'tins_', 'thirsts_', 'dissent_', 'collision_', 'rebel_', 'revelations_', 'hauteur_', 'Panama_', 'smoky_', 'wrong--why_', 'oath--to_', 'possible_', 'sailing_', 'exchange_', 'Shards_', 'pay_', 'scornful_', 'bllcr10_', 'devoid_', 'Victoria_', 'monument_', 'straw_', 'dog_', 'resignation_', 'seventeenth-century_', 'Pursuer_', 'Damn_', 'speech_', 'seem_', 'habitation_', 'Free-thought_', 'wholly_', 'pencil_', 'green_', 'beyond_', 'violence_', 'ruby_', 'glaring_', 'gesture_', 'LAST_', 'shabbier_', 'shade_', 'encircling_', 'medicine-man_', 'Divine_', 'dead_', 'inappropriate_', 'early_', 'horse-pond_', 'scuttled_', 'nooks_', 'fading_', 'telling_', 'concede_', 'equality_', 'discuss_', 'promising_', 'meditative_', 'disarmed_', 'Lucretius_', 'attempt_', 'citizen_', 'innocently_', 'Mafeking_', 'decorated_', 'ostensible_', 'scraggy_', 'arching_', 'Busy_', 'however_', 'smitten_', 'wandered_', 'realized_', 'courteous_', 'status_', 'Beauchamp_', 'curtain_', 'better_', 'facts_', 'meat_', 'hinges_', 'instantaneous_', 'Be_', 'paid_', 'grotesque_', 'serve_', 'ardent_', 'howled_', 'Purple_', 'it--and_', 'version_', 'about_', 'bitterly_', 'Dionysus_', 'respect_', 'seascape_', 'concern_', 'arrangements_', 'important--justice_', 'DIES_', 'records_', 'delusions_', 'pink_', 'battery_', 'Lyonesse_', 'ANYTHING_', 'category_', 'winning_', '*_', 'silently_', 'frosty_', 'element_', 'insisted_', 'sallow_', 'custom_', 'hateful_', 'catlike_', 'sickness_', 'Free-thinker_', 'with_', 'younger_', 'disgrace_', 'subconsciousness_', 'grown_', 'drunkard_', 'Prussian_', 'black-clad_', 'pleasant_', 'past_', 'poetry_', 'uttermost_', 'smashed_', 'horses_', 'think----_', 'potted_', 'smilingly_', 'heartily_', 'Hertfordshire_', 'November_', 'sophistry_', 'supposing_', 'dreaming--you_', 'proletarian_', 'bent_', 'quarter_', 'war_', 'hieroglyphic_', 'occurs_', 'self-control_', 'Dead_', 'queried_', 'throbbing_', 'Physical_', 'decent_', 'Wimpey_', 'pawnbroker_', 'far_', 'really_', 'excitedly_', 'key_', 'investigate_', 'angles_', 'People_', 'figured_', 'housekeeper_', 'decay_', 'base_', 'pulsation_', 'imprison_', 'hail_', 'till_', 'squeak_', 'demeanour_', 'stalk_', 'X_', 'madman_', 'developed_', 'philosophy_', 'degradedly_', 'District_', 'received_', 'York_', 'deserts_', 'caution_', 'nationality_', 'childhood_', 'underfed_', 'brains_', 'novelist_', 'tended_', 'metal_', 'He_', 'accountable_', 'basket_', 'fire_', 'George_', 'ragging_', '000_', 'valuable_', 'master_', 'staggering_', 'carpentry_', 'ourselves_', 'sundered_', 'Cockney_', 'belief_', 'Queen_', 'Divinity_', 'foliage_', 'chamber_', '_does__', 'ken_', 'fate_', 'coloured_', 'conspicuous_', 'immature_', 'titanic_', 'bootlace_', 'Carolina_', 'impetus_', 'thistle_', 'clov ...
